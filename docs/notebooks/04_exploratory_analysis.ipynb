# %% [markdown]
# # Notebook 04: Exploratory Data Analysis
# ## Netflix Content Strategy Analysis
#
# **Business Context**: This notebook answers 10 core business questions about Netflix's content strategy through 35 purposeful visualizations. Every chart is tied to a specific business question.
#
# **Business Questions**:
# 1. How has Netflix's content library evolved over time?
# 2. Which countries dominate Netflix?
# 3. Which genres are growing?
# 4. Which ratings dominate?
# 5. Does Netflix focus more on Movies or TV Shows?
# 6. How diverse is Netflix's catalogue?
# 7. Which directors contribute the most content?
# 8. Which actors appear most frequently?
# 9. What trends exist in content additions?
# 10. Where are the data quality gaps?
#
# **Input**: `data/processed/netflix_features.csv`
# **Output**: 35 charts in `images/charts/<category>/`

# %% [markdown]
# ## 0. Setup & Imports

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
from IPython.display import display, Image

from src.config import FEATURES_CSV, RAW_CSV, ensure_dirs
from src.utils import load_csv, compute_kpis
from src.visualization import (
    apply_global_style,
    # Overview
    plot_content_type_donut,
    plot_top_ratings_bar,
    plot_content_type_by_year_area,
    plot_kpi_summary_bar,
    plot_decade_distribution,
    # Timeline
    plot_yearly_additions_line,
    plot_monthly_heatmap,
    plot_cumulative_growth,
    plot_yoy_growth_rate,
    plot_weekday_additions,
    # Country
    plot_top_countries_bar,
    plot_country_treemap,
    plot_country_content_type_stacked,
    plot_country_diversity_bar,
    plot_choropleth_map,
    # Genre
    plot_top_genres_bar,
    plot_genre_treemap,
    plot_genre_sunburst,
    plot_genre_by_type_bar,
    plot_genre_heatmap,
    # Ratings
    plot_rating_distribution_bar,
    plot_rating_by_type_grouped,
    plot_rating_pie,
    plot_rating_heatmap_by_year,
    # Duration
    plot_movie_duration_histogram,
    plot_duration_boxplot,
    plot_tv_seasons_bar,
    # Directors
    plot_top_directors_bar,
    plot_director_content_type_bubble,
    # Cast
    plot_top_actors_bar,
    plot_cast_count_distribution,
    # Missing
    plot_missing_value_heatmap,
    plot_missing_value_bar,
    # Features
    plot_duration_category_dist,
    plot_release_decade_by_type,
)

apply_global_style()
ensure_dirs()
print('Setup complete.')
# Out:
# Setup complete.

# %% [markdown]
# ## 1. Load Data

# %%
df = load_csv(FEATURES_CSV)
df_raw = load_csv(RAW_CSV)

# Reconstruct genres list
df['genres'] = df['genres'].apply(
    lambda x: [g.strip() for g in str(x).split(',') if g.strip()] if pd.notna(x) else []
)
df['date_added'] = pd.to_datetime(df['date_added'], errors='coerce')

print(f'Dataset shape: {df.shape}')
display(df.head(3))
# Out:
# 13:01:25 | INFO | Loaded netflix_features.csv: 8,807 rows × 31 cols
# 13:01:25 | INFO | Loaded netflix_titles.csv: 8,807 rows × 12 cols
# Dataset shape: (8807, 31)
#   show_id     type                 title          director  \
# 0      s1    Movie  Dick Johnson Is Dead   Kirsten Johnson
# 1      s2  Tv Show         Blood & Water  Unknown Director
# 2      s3  Tv Show             Ganglands   Julien Leclercq
#
#                                                 cast        country  \
# 0                                       Unknown Cast  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...        Unknown
#
#   date_added  release_year rating   duration  ... year_added month_added  \
# 0 2021-09-25          2020  PG-13     90 min  ...     2021.0   September
# 1 2021-09-24          2021  TV-MA  2 Seasons  ...     2021.0   September
# ...

# %% [markdown]
# ## 2. KPI Dashboard
#
# Computing all 12 locked business KPIs before diving into individual analyses.

# %%
kpis = compute_kpis(df)
print('=== 12 BUSINESS KPIs ===')
for k, v in kpis.items():
    print(f'  {k:<35} : {v}')
# Out:
# === 12 BUSINESS KPIs ===
#   Total Titles                        : 8807
#   Movies                              : 6131
#   TV Shows                            : 0
#   Movie vs TV Show Ratio              : 6131:0
#   Average Movie Duration (min)        : 99.6
#   Average TV Show Seasons             : nan
#   Content Growth Rate (YoY %)         : -20.3
#   Top Producing Country               : United States
#   Top Genre                           : Dramas
#   Content Added per Year (avg)        : 628.4
#   Median Movie Age (years)            : 10.0
#   Genre Diversity                     : 36
#   Country Diversity                   : 122

# %% [markdown]
# ---
# ## Section 1: Overview (5 Charts)
#
# **Business Question 5**: Does Netflix focus more on Movies or TV Shows?

# %%
# Chart Overview-1: Content Type Donut
fig = plot_content_type_donut(df)
plt.show()
print('Observation: Netflix catalog composition by content type.')
# Out:
# 13:01:25 | INFO | Chart saved → images\charts\overview\01_content_type_donut.png
# Observation: Netflix catalog composition by content type.

# %%
# Chart Overview-2: Top Ratings Bar
fig = plot_top_ratings_bar(df)
plt.show()
print('Observation: TV-MA dominates, signaling a mature-audience strategy.')
# Out:
# 13:01:25 | INFO | Chart saved → images\charts\overview\02_top_ratings_bar.png
# Observation: TV-MA dominates, signaling a mature-audience strategy.

# %%
# Chart Overview-3: Content Type by Year Area
fig = plot_content_type_by_year_area(df)
plt.show()
print('Observation: How the Movie/TV Show balance shifted over time.')
# Out:
# 13:01:25 | INFO | Chart saved → images\charts\overview\03_content_type_by_year_area.png
# Observation: How the Movie/TV Show balance shifted over time.

# %%
# Chart Overview-4: KPI Summary Bar
fig = plot_kpi_summary_bar(kpis)
if fig:
    plt.show()
# Out:
# 13:01:26 | INFO | Chart saved → images\charts\overview\04_kpi_summary_bar.png

# %%
# Chart Overview-5: Decade Distribution
fig = plot_decade_distribution(df)
plt.show()
print('Observation: 2010s content dominates — Netflix primarily acquired and produced 2010s-era content.')
# Out:
# 13:01:26 | INFO | Chart saved → images\charts\overview\05_decade_distribution.png
# Observation: 2010s content dominates — Netflix primarily acquired and produced 2010s-era content.

# %% [markdown]
# ---
# ## Section 2: Timeline Analysis (5 Charts)
#
# **Business Questions 1 & 9**: How has the library evolved? What trends exist in content additions?

# %%
# Chart Timeline-1: Yearly Additions Line
fig = plot_yearly_additions_line(df)
plt.show()
# Out:
# 13:01:26 | INFO | Chart saved → images\charts\timeline\01_yearly_additions_line.png

# %%
# Chart Timeline-2: Monthly Heatmap
fig = plot_monthly_heatmap(df)
plt.show()
# Out:
# 13:01:26 | INFO | Chart saved → images\charts\timeline\02_monthly_heatmap.png

# %%
# Chart Timeline-3: Cumulative Growth
fig = plot_cumulative_growth(df)
plt.show()
# Out:
# 13:01:26 | INFO | Chart saved → images\charts\timeline\03_cumulative_growth.png

# %%
# Chart Timeline-4: YoY Growth Rate
fig = plot_yoy_growth_rate(df)
plt.show()
# Out:
# 13:01:26 | INFO | Chart saved → images\charts\timeline\04_yoy_growth_rate.png

# %%
# Chart Timeline-5: Weekday Additions
fig = plot_weekday_additions(df)
plt.show()
# Out:
# 13:01:26 | INFO | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 13:01:26 | INFO | Using categorical units to plot a list of strings that are all parsable as floats or dates. If these strings should be plotted as numbers, cast to the appropriate data type before plotting.
# 13:01:27 | INFO | Chart saved → images\charts\timeline\05_weekday_additions.png

# %% [markdown]
# ---
# ## Section 3: Country Analysis (5 Charts)
#
# **Business Questions 2 & 6**: Which countries dominate Netflix? How diverse is the catalogue?

# %%
# Chart Country-1: Top Countries Bar
fig = plot_top_countries_bar(df)
plt.show()
# Out:
# 13:01:27 | INFO | Chart saved → images\charts\country\01_top_countries_bar.png

# %%
# Chart Country-2: Country Treemap (Plotly — interactive)
fig = plot_country_treemap(df)
fig.show()
# Out:
# 13:01:27 | INFO | Chromium init'ed with kwargs {}
# 13:01:27 | INFO | Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# 13:01:27 | INFO | Temp directory created: C:\Users\chait\AppData\Local\Temp\tmpnww9fl7a.
# 13:01:27 | INFO | Opening browser.
# 13:01:27 | INFO | Temp directory created: C:\Users\chait\AppData\Local\Temp\tmpkqc6kt3p.
# 13:01:27 | INFO | Temporary directory at: C:\Users\chait\AppData\Local\Temp\tmpkqc6kt3p
# 13:01:28 | INFO | Conforming 1 to file:///C:/Users/chait/AppData/Local/Temp/tmpnww9fl7a/index.html
# 13:01:29 | INFO | Getting tab from queue (has 1)
# 13:01:29 | INFO | Got 18C2
# 13:01:29 | INFO | Reloading tab 18C2 before return.
# 13:01:29 | INFO | Putting tab 18C2 back (queue size: 0).
# 13:01:29 | INFO | Waiting for all cleanups to finish.
# 13:01:29 | INFO | Exiting Kaleido.
# 13:01:29 | INFO | TemporaryDirectory.cleanup() worked.
# 13:01:29 | INFO | shutil.rmtree worked.
# 13:01:29 | INFO | Closing browser.
# ...

# %%
# Chart Country-3: Country Content Type Stacked
fig = plot_country_content_type_stacked(df)
plt.show()
# Out:
# 13:01:32 | INFO | Chart saved → images\charts\country\03_country_type_stacked.png

# %%
# Chart Country-4: Country Diversity Over Years
fig = plot_country_diversity_bar(df)
plt.show()
# Out:
# 13:01:32 | INFO | Chart saved → images\charts\country\04_country_diversity_bar.png

# %%
# Chart Country-5: Choropleth World Map (Plotly — interactive)
fig = plot_choropleth_map(df)
fig.show()
# Out:
# 13:01:32 | INFO | Chromium init'ed with kwargs {}
# 13:01:32 | INFO | Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# 13:01:32 | INFO | Temp directory created: C:\Users\chait\AppData\Local\Temp\tmpwhbziq9x.
# 13:01:32 | INFO | Opening browser.
# 13:01:32 | INFO | Temp directory created: C:\Users\chait\AppData\Local\Temp\tmphgidxnlw.
# 13:01:32 | INFO | Temporary directory at: C:\Users\chait\AppData\Local\Temp\tmphgidxnlw
# 13:01:32 | INFO | Conforming 1 to file:///C:/Users/chait/AppData/Local/Temp/tmpwhbziq9x/index.html
# 13:01:33 | INFO | Getting tab from queue (has 1)
# 13:01:33 | INFO | Got 5688
# 13:01:35 | INFO | Reloading tab 5688 before return.
# 13:01:35 | INFO | Putting tab 5688 back (queue size: 0).
# 13:01:35 | INFO | Waiting for all cleanups to finish.
# 13:01:35 | INFO | Exiting Kaleido.
# 13:01:35 | INFO | TemporaryDirectory.cleanup() worked.
# 13:01:35 | INFO | shutil.rmtree worked.
# 13:01:35 | INFO | Closing browser.
# ...

# %% [markdown]
# ---
# ## Section 4: Genre Analysis (5 Charts)
#
# **Business Question 3**: Which genres are growing?

# %%
# Chart Genre-1: Top Genres Bar
fig = plot_top_genres_bar(df)
plt.show()
# Out:
# 13:01:35 | INFO | TemporaryDirectory.cleanup() worked.
# 13:01:35 | INFO | shutil.rmtree worked.
# 13:01:35 | INFO | Chart saved → images\charts\genre\01_top_genres_bar.png

# %%
# Chart Genre-2: Genre Treemap (Plotly — interactive)
fig = plot_genre_treemap(df)
fig.show()
# Out:
# 13:01:35 | INFO | Chromium init'ed with kwargs {}
# 13:01:35 | INFO | Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# 13:01:35 | INFO | Temp directory created: C:\Users\chait\AppData\Local\Temp\tmptipqvsx8.
# 13:01:35 | INFO | Opening browser.
# 13:01:35 | INFO | Temp directory created: C:\Users\chait\AppData\Local\Temp\tmp1srmbno3.
# 13:01:36 | INFO | Temporary directory at: C:\Users\chait\AppData\Local\Temp\tmp1srmbno3
# 13:01:36 | INFO | Conforming 1 to file:///C:/Users/chait/AppData/Local/Temp/tmptipqvsx8/index.html
# 13:01:37 | INFO | Getting tab from queue (has 1)
# 13:01:37 | INFO | Got DA68
# 13:01:37 | INFO | Reloading tab DA68 before return.
# 13:01:37 | INFO | Putting tab DA68 back (queue size: 0).
# 13:01:37 | INFO | Waiting for all cleanups to finish.
# 13:01:37 | INFO | Exiting Kaleido.
# 13:01:37 | INFO | TemporaryDirectory.cleanup() worked.
# 13:01:37 | INFO | shutil.rmtree worked.
# 13:01:37 | INFO | Closing browser.
# ...

# %%
# Chart Genre-3: Genre Sunburst (Plotly — interactive)
fig = plot_genre_sunburst(df)
fig.show()
# Out:
# 13:01:37 | INFO | TemporaryDirectory.cleanup() worked.
# 13:01:37 | INFO | shutil.rmtree worked.
# 13:01:37 | INFO | Chromium init'ed with kwargs {}
# 13:01:37 | INFO | Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# 13:01:37 | INFO | Temp directory created: C:\Users\chait\AppData\Local\Temp\tmpvyad2vh8.
# 13:01:37 | INFO | Opening browser.
# 13:01:37 | INFO | Temp directory created: C:\Users\chait\AppData\Local\Temp\tmpeniqbgaf.
# 13:01:37 | INFO | Temporary directory at: C:\Users\chait\AppData\Local\Temp\tmpeniqbgaf
# 13:01:38 | INFO | Conforming 1 to file:///C:/Users/chait/AppData/Local/Temp/tmpvyad2vh8/index.html
# 13:01:39 | INFO | Getting tab from queue (has 1)
# 13:01:39 | INFO | Got 8DD5
# 13:01:39 | INFO | Reloading tab 8DD5 before return.
# 13:01:39 | INFO | Putting tab 8DD5 back (queue size: 0).
# 13:01:39 | INFO | Waiting for all cleanups to finish.
# 13:01:39 | INFO | Exiting Kaleido.
# 13:01:39 | INFO | TemporaryDirectory.cleanup() worked.
# ...

# %%
# Chart Genre-4: Genre by Type Bar
fig = plot_genre_by_type_bar(df)
plt.show()
# Out:
# 13:01:39 | INFO | TemporaryDirectory.cleanup() worked.
# 13:01:39 | INFO | shutil.rmtree worked.
# 13:01:40 | INFO | Chart saved → images\charts\genre\04_genre_by_type_bar.png

# %%
# Chart Genre-5: Genre Heatmap by Year
fig = plot_genre_heatmap(df)
plt.show()
# Out:
# 13:01:40 | INFO | Chart saved → images\charts\genre\05_genre_heatmap.png

# %% [markdown]
# ---
# ## Section 5: Ratings Analysis (4 Charts)
#
# **Business Question 4**: Which ratings dominate?

# %%
fig = plot_rating_distribution_bar(df)
plt.show()
# Out:
# 13:01:40 | INFO | Chart saved → images\charts\ratings\01_rating_distribution_bar.png

# %%
fig = plot_rating_by_type_grouped(df)
plt.show()
# Out:
# 13:01:40 | INFO | Chart saved → images\charts\ratings\02_rating_by_type_grouped.png

# %%
fig = plot_rating_pie(df)
plt.show()
# Out:
# 13:01:40 | INFO | Chart saved → images\charts\ratings\03_rating_pie.png

# %%
fig = plot_rating_heatmap_by_year(df)
plt.show()
# Out:
# 13:01:41 | INFO | Chart saved → images\charts\ratings\04_rating_heatmap_by_year.png

# %% [markdown]
# ---
# ## Section 6: Duration Analysis (3 Charts)

# %%
fig = plot_movie_duration_histogram(df)
plt.show()
# Out:
# 13:01:41 | INFO | Chart saved → images\charts\duration\01_movie_duration_histogram.png

# %%
fig = plot_duration_boxplot(df)
plt.show()
# Out:
# 13:01:41 | INFO | Chart saved → images\charts\duration\02_duration_boxplot.png

# %%
fig = plot_tv_seasons_bar(df)
plt.show()
# Out:
# 13:01:41 | INFO | Chart saved → images\charts\duration\03_tv_seasons_bar.png

# %% [markdown]
# ---
# ## Section 7: Director Analysis (2 Charts)
#
# **Business Question 7**: Which directors contribute the most content?

# %%
fig = plot_top_directors_bar(df)
plt.show()
# Out:
# 13:01:41 | INFO | Chart saved → images\charts\directors\01_top_directors_bar.png

# %%
fig = plot_director_content_type_bubble(df)
fig.show()
# Out:
# 13:01:41 | INFO | Chromium init'ed with kwargs {}
# 13:01:41 | INFO | Found chromium path: C:\Program Files\Google\Chrome\Application\chrome.exe
# 13:01:41 | INFO | Temp directory created: C:\Users\chait\AppData\Local\Temp\tmpi_he7599.
# 13:01:41 | INFO | Opening browser.
# 13:01:41 | INFO | Temp directory created: C:\Users\chait\AppData\Local\Temp\tmpz83_z_0g.
# 13:01:41 | INFO | Temporary directory at: C:\Users\chait\AppData\Local\Temp\tmpz83_z_0g
# 13:01:42 | INFO | Conforming 1 to file:///C:/Users/chait/AppData/Local/Temp/tmpi_he7599/index.html
# 13:01:43 | INFO | Getting tab from queue (has 1)
# 13:01:43 | INFO | Got E5E5
# 13:01:43 | INFO | Reloading tab E5E5 before return.
# 13:01:43 | INFO | Putting tab E5E5 back (queue size: 0).
# 13:01:43 | INFO | Waiting for all cleanups to finish.
# 13:01:43 | INFO | Exiting Kaleido.
# 13:01:43 | INFO | TemporaryDirectory.cleanup() worked.
# 13:01:43 | INFO | shutil.rmtree worked.
# 13:01:43 | INFO | Closing browser.
# ...

# %% [markdown]
# ---
# ## Section 8: Cast Analysis (2 Charts)
#
# **Business Question 8**: Which actors appear most frequently?

# %%
fig = plot_top_actors_bar(df)
plt.show()
# Out:
# 13:01:43 | INFO | TemporaryDirectory.cleanup() worked.
# 13:01:43 | INFO | shutil.rmtree worked.
# 13:01:43 | INFO | Chart saved → images\charts\cast\01_top_actors_bar.png

# %%
fig = plot_cast_count_distribution(df)
plt.show()
# Out:
# 13:01:44 | INFO | Chart saved → images\charts\cast\02_cast_count_distribution.png

# %% [markdown]
# ---
# ## Section 9: Missing Value Analysis (2 Charts)
#
# **Business Question 10**: Where are the data quality gaps?

# %%
fig = plot_missing_value_heatmap(df_raw)
plt.show()
# Out:
# 13:01:44 | INFO | Chart saved → images\charts\missing\01_missing_value_heatmap.png

# %%
fig = plot_missing_value_bar(df_raw)
plt.show()
# Out:
# 13:01:44 | INFO | Chart saved → images\charts\missing\02_missing_value_bar.png

# %% [markdown]
# ---
# ## Section 10: Feature Engineering Validation (2 Charts)

# %%
fig = plot_duration_category_dist(df)
plt.show()
# Out:
# 13:01:44 | INFO | Chart saved → images\charts\features\01_duration_category_dist.png

# %%
fig = plot_release_decade_by_type(df)
plt.show()
# Out:
# 13:01:44 | INFO | Chart saved → images\charts\features\02_release_decade_by_type.png

# %% [markdown]
# ---
# ## EDA Complete
#
# All 35 charts have been generated and saved to `images/charts/<category>/`.
#
# **Chart Inventory**:
# | Category | Charts |
# |----------|--------|
# | Overview | 5 |
# | Timeline | 5 |
# | Country | 5 |
# | Genre | 5 |
# | Ratings | 4 |
# | Duration | 3 |
# | Directors | 2 |
# | Cast | 2 |
# | Missing Values | 2 |
# | Feature Engineering | 2 |
# | **Total** | **35** |
#
# **Next Step**: Proceed to `05_business_insights.ipynb` to synthesize findings into business insights and recommendations.
